# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data/Clustering_ProductCategories.csv')

# %%
df = df.dropna()

# %%
#sanity to check if there is one row per ASIN/MARKETPLACE/BRAND

df.groupby(['ASIN','MARKETPLACE','BRAND_NAME']).size().max()
# Out:
# 1

# %%
df.to_csv('preprocessed_data/ProductMainAndSubCategory.csv',index=False)

# %%
df
# Out:
#             ASIN MARKETPLACE REGION BRAND_NAME              MAIN_CATEGORY  \
# 1     B071LM6NRM          PL     EU    Espring     Beauty & Personal Care
# 2     B06X6G3FP1          ES     EU    Espring      Arts, Crafts & Sewing
# 3     B07NVDQCKB          ES     EU    Espring          Sports & Outdoors
# 4     B07YSCWK2F          TR     EU    Tritart      Arts, Crafts & Sewing
# 5     B072LXQPCH          PL     EU        H&S     Beauty & Personal Care
# ...          ...         ...    ...        ...                        ...
# 7301  B01MXLKX0C          NL     EU    Espring                 Automotive
# 7302  B09M76QR53          ES     EU    Espring     Beauty & Personal Care
# 7303  B09LVD7TV4          UK     UK    Espring  Clothing, Shoes & Jewelry
# 7304  B06Y5V63YZ  NON-AMAZON     EU    Espring               Pet Supplies
# 7305  B07GBK5SQL          IT     EU        H&S             Home & Kitchen
#
#                           SUB_CATEGORY
# 1                 Shave & Hair Removal
# ...
